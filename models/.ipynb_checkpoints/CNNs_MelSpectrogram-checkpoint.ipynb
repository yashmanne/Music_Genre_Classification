# %%
# %%time
import numpy as np
# from tempfile import TemporaryFile
import os
import pickle
import random 
import operator
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as ipd
import time
# Out:
# CPU times: user 814 ms, sys: 311 ms, total: 1.13 s
# Wall time: 7.81 s

# %%
# %%time
import librosa 
import librosa.display
# Out:
# CPU times: user 563 ms, sys: 489 ms, total: 1.05 s
# Wall time: 11.7 s

# %%
import tensorflow as tf
# Out:
# 2022-04-24 15:50:09.763164: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
# %%time
# directory = "../data/"
# data = []
# classes = []
# for folder in os.listdir(directory):
#     if folder=="mf_files":
#         continue
#     for file in os.listdir(directory+folder):  
#         sig, rate = librosa.load(directory+folder+"/"+file)
        
#         # MFCC
#         mfcc_feat = librosa.feature.mfcc(y =sig, sr= rate)
#         mfcc_mean = mfcc_feat.mean(1)
#         mfcc_var = mfcc_feat.var(1)
        
#         # Spectral Centroid
#         spec_centroid = librosa.feature.spectral_centroid(y= sig, sr = rate)
#         spec_centroid_mean = spec_centroid.mean(1)
#         spec_centroid_var = spec_centroid.var(1)
        
#         # Spectral-Bandwidth
#         spec_band = librosa.feature.spectral_bandwidth(y=sig, sr= rate)
#         spec_band_mean = spec_band.mean(1)
#         spec_band_var = spec_band.var(1)
        
#         # Zero-Crossing Rate
#         zero_cr = librosa.feature.zero_crossing_rate(sig)
#         zero_cr_mean = zero_cr.mean(1)
#         zero_cr_var = zero_cr.var(1)
        
#         # Spectral-Rolloff
#         rolloff = librosa.feature.spectral_rolloff(y = sig, sr = rate)
#         rolloff_mean = rolloff.mean(1)
#         rolloff_var = rolloff.var(1)
        
#         # Tempo
#         onset_env = librosa.onset.onset_strength(y=sig, sr=rate)
#         tempo = librosa.beat.tempo(onset_envelope=onset_env, sr=rate)
        
#         # Chroma
#         chroma = librosa.feature.chroma_stft(y=sig, sr = rate)
#         chroma_mean = chroma.mean(1) 
#         chroma_var = chroma.var(1)
        
#         # RMS
#         S, phase = librosa.magphase(librosa.stft(sig))
#         rms = librosa.feature.rms(S=S)
#         rms_mean = rms.mean(1)
#         rms_var = rms.var(1)
        
#         data.append(np.array([mfcc_mean, mfcc_var,
#                              spec_centroid_mean, spec_centroid_var,
#                              spec_band_mean, spec_band_var,
#                              zero_cr_mean, zero_cr_var,
#                              rolloff_mean, rolloff_var,
#                              tempo,
#                              chroma_mean, chroma_var,
#                              rms_mean, rms_var]).flatten())
#         classes.append(folder)
# df = np.array([np.array(np.hstack(row)) for row in data])
# pd.DataFrame(df).to_csv("all_features.csv")

# %%
# %%time
directory = "../data/"
data = []
classes = []
for folder in os.listdir(directory):
    if folder=="mf_files":
        continue
    for file in os.listdir(directory+folder):  
        sig, rate = librosa.load(directory+folder+"/"+file)
        mel = librosa.feature.melspectrogram(y=sig, sr=rate)
        # scale to between 0 and 1
        mel_db = (librosa.power_to_db(mel, ref= np.max)+80)/80
        data.append(mel_db)
        classes.append(folder)
# Out:
# CPU times: user 3min 55s, sys: 23 s, total: 4min 18s
# Wall time: 1min 11s

# %%
poor_data = []
for i in range(len(data)):
#     print(data[i].shape)
    if data[i].shape != (128,1293):
        print(i, "\t", data[i].shape)
        poor_data.append(i)
print(len(poor_data))
# Out:
# 4 	 (128, 1305)
# 64 	 (128, 1308)
# 65 	 (128, 1310)
# 73 	 (128, 1292)
# 83 	 (128, 1292)
# 112 	 (128, 1292)
# 113 	 (128, 1308)
# 148 	 (128, 1292)
# 155 	 (128, 1307)
# 162 	 (128, 1303)
# 167 	 (128, 1296)
# 169 	 (128, 1292)
# 170 	 (128, 1297)
# 185 	 (128, 1296)
# 405 	 (128, 1300)
# 427 	 (128, 1308)
# 437 	 (128, 1294)
# 440 	 (128, 1304)
# 463 	 (128, 1308)
# 473 	 (128, 1303)
# 487 	 (128, 1301)
# 490 	 (128, 1313)
# 606 	 (128, 1314)
# 608 	 (128, 1296)
# 615 	 (128, 1309)
# 617 	 (128, 1296)
# 646 	 (128, 1292)
# 647 	 (128, 1300)
# 671 	 (128, 1292)
# 696 	 (128, 1308)
# 703 	 (128, 1298)
# 747 	 (128, 1296)
# 755 	 (128, 1305)
# 756 	 (128, 1299)
# 765 	 (128, 1305)
# 791 	 (128, 1292)
# 798 	 (128, 1305)
# 799 	 (128, 1302)
# 800 	 (128, 1320)
# 801 	 (128, 1320)
# 804 	 (128, 1320)
# 805 	 (128, 1305)
# 810 	 (128, 1305)
# 811 	 (128, 1320)
# 814 	 (128, 1300)
# 815 	 (128, 1320)
# 822 	 (128, 1308)
# 831 	 (128, 1308)
# 832 	 (128, 1320)
# 845 	 (128, 1298)
# 846 	 (128, 1320)
# 852 	 (128, 1290)
# 859 	 (128, 1292)
# 870 	 (128, 1320)
# 877 	 (128, 1320)
# 896 	 (128, 1320)
# 56

# %%
usable_data = np.stack([element for i,element in enumerate(data) if i not in poor_data])
usable_classes = np.array([element for i,element in enumerate(classes) if i not in poor_data])

usable_data = usable_data[:,:,:, np.newaxis]
print(usable_data.shape)
print(usable_classes.shape)
# Out:
# (944, 128, 1293, 1)
# (944,)

# %%
label_dict = {}
for i, element in enumerate(np.unique(usable_classes)):
    label_dict[element] = i
print(label_dict)
# convert from string to int
# Out:
# {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4, 'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}

# %%
usable_labels = np.array([label_dict[element] for element in list(usable_classes)])

# %%
inv_labels = {v: k for k, v in label_dict.items()}

# %%
from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(usable_data, 
                                                usable_labels,
                                                test_size = 0.25, 
                                                random_state=29,
                                                stratify = usable_labels)

# %%
trainX.shape
# Out:
# (708, 128, 1293, 1)

# %% [markdown]
# ### MFCC: No Scaling

# %% [markdown]
# Overfitting:
# * Regularization
# * Batch Normalization
# * Dropout Layers:
#     * tf.keras.layers.Dropout(rate=0.2)
#     * 0.20-0.3 in RNN and 0.4-.5 in CNN
#
# Try with ReLU layers
# or Elu or SELU layers:
# * tf.keras.layers.Dense(64, kernel_initializer='lecun_normal', activation='selu')
# * tf.keras.layers.Dense(64, kernel_initializer='he_normal',
#                                 activation= 'elu')

# %%
def plot_results(fit):
    plt.figure(figsize=(20,15))
    fig, ax = plt.subplots(2)
    # accuracy subplot
    ax[0].plot(fit.history["accuracy"], label="train")
    ax[0].plot(fit.history["val_accuracy"], label="test")    
    ax[0].set_ylabel("Accuracy")
    ax[0].legend(loc="lower right")
    ax[0].set_title("Accuracy")
    
    # Error subplot
    ax[1].plot(fit.history["loss"], label="train error")
    ax[1].plot(fit.history["val_loss"], label="test error")    
    ax[1].set_ylabel("Error")
    ax[1].set_xlabel("Epoch")
    ax[1].legend(loc="upper right")
    ax[1].set_title("Error")
    plt.tight_layout()
    plt.show()

# %%
train_times = []

# %% [markdown]
# ### Basic CNN
# ---
# Book's example for MNIST. Also incorporate Early Stopping:

# %%
# %%time
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=64, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same",
                           input_shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3])),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    
    tf.keras.layers.Conv2D(filters=128, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.Conv2D(filters=128, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    
    tf.keras.layers.Conv2D(filters=256, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.Conv2D(filters=256, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(512, activation= "relu", 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.01),
    tf.keras.layers.Dense(256, activation = "relu", 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.03),
    tf.keras.layers.Dense(128, activation = "relu", 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.01),
    tf.keras.layers.Dense(64, activation = "relu", 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.01),
    tf.keras.layers.Dense(10, activation = "linear")
])
## get output layer as logits for each class 
##(we can use softmax to get probabilities, but doing so makes model unstable:
# https://www.tensorflow.org/tutorials/quickstart/beginner
model.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

start = time.time()
fit = model.fit(trainX, trainY,
                validation_data = (testX,testY),
                epochs = 100,
                callbacks = [callback])
stop = time.time()
train_times.append(stop-start)


plot_results(fit)

probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
predictions = probability_model.predict(testX)
pred_labels = [np.argmax(prediction) for i,prediction in enumerate(predictions)]

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

ConfusionMatrixDisplay.from_predictions(
    y_true = [inv_labels[e] for i,e in enumerate(testY)],
    y_pred = [inv_labels[e] for i,e in enumerate(pred_labels)], 
    xticks_rotation= "vertical")
print(accuracy_score(testY,pred_labels))
# Out:
# 2022-04-23 23:28:35.965778: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-23 23:28:35.970073: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-04-23 23:28:36.122962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0b:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.92GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-23 23:28:36.124659: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:0e:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.92GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-23 23:28:36.126293: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:0f:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.92GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-23 23:28:36.127957: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:15:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-23 23:28:36.127989: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-23 23:28:36.327008: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-23 23:28:36.327087: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-23 23:28:36.418656: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-23 23:28:36.586199: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-23 23:28:36.716734: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-23 23:28:36.848633: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-23 23:28:37.049216: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-23 23:28:37.069122: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2022-04-23 23:28:37.070246: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-23 23:28:37.070674: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-23 23:28:37.427555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0b:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.92GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-23 23:28:37.429355: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:0e:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.92GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-23 23:28:37.431164: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:0f:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.92GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-23 23:28:37.432902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:15:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-23 23:28:37.432979: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-23 23:28:37.433009: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-23 23:28:37.433032: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-23 23:28:37.433054: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-23 23:28:37.433076: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-23 23:28:37.433099: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-23 23:28:37.433121: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-23 23:28:37.433143: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-23 23:28:37.447032: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2022-04-23 23:28:37.447120: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-23 23:28:41.698957: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-23 23:28:41.699000: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1 2 3
# 2022-04-23 23:28:41.699076: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y Y Y
# 2022-04-23 23:28:41.699082: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N Y Y
# 2022-04-23 23:28:41.699087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 2:   Y Y N Y
# 2022-04-23 23:28:41.699092: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 3:   Y Y Y N
# 2022-04-23 23:28:41.709340: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 11344 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:0b:00.0, compute capability: 3.7)
# 2022-04-23 23:28:41.731380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 11344 MB memory) -> physical GPU (device: 1, name: Tesla K80, pci bus id: 0000:0e:00.0, compute capability: 3.7)
# 2022-04-23 23:28:41.734821: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 11344 MB memory) -> physical GPU (device: 2, name: Tesla K80, pci bus id: 0000:0f:00.0, compute capability: 3.7)
# 2022-04-23 23:28:41.738086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 
100
# 23/23 [==============================] - 40s 2s/step - loss: 0.9290 - accuracy: 0.9001 - val_loss: 2.8295 - val_accuracy: 0.4703
# Epoch 15/100
# 23/23 [==============================] - 40s 2s/step - loss: 1.1252 - accuracy: 0.8045 - val_loss: 3.3848 - val_accuracy: 0.4703
# Epoch 16/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.8348 - accuracy: 0.9303 - val_loss: 3.4863 - val_accuracy: 0.4407
# Epoch 17/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.7852 - accuracy: 0.9362 - val_loss: 3.5578 - val_accuracy: 0.4534
# Epoch 18/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.8243 - accuracy: 0.9357 - val_loss: 2.9965 - val_accuracy: 0.5085
# Epoch 19/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.7528 - accuracy: 0.9668 - val_loss: 2.9700 - val_accuracy: 0.4958
# Epoch 20/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.6513 - accuracy: 0.9874 - val_loss: 3.5424 - val_accuracy: 0.4619
# Epoch 21/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.6349 - accuracy: 0.9714 - val_loss: 3.6672 - val_accuracy: 0.5085
# Epoch 22/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.5645 - accuracy: 0.9891 - val_loss: 3.6885 - val_accuracy: 0.4831
# Epoch 23/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.5213 - accuracy: 0.9896 - val_loss: 2.9212 - val_accuracy: 0.4958
# Epoch 24/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.5495 - accuracy: 0.9764 - val_loss: 4.2176 - val_accuracy: 0.5000
# Epoch 25/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.6304 - accuracy: 0.9622 - val_loss: 2.7296 - val_accuracy: 0.4576
# Epoch 26/100
# 23/23 [==============================] - 41s 2s/step - loss: 0.6182 - accuracy: 0.9644 - val_loss: 3.4888 - val_accuracy: 0.4831
# Epoch 27/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.5689 - accuracy: 0.9755 - val_loss: 3.3939 - val_accuracy: 0.4873
# Epoch 28/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.5753 - accuracy: 0.9649 - val_loss: 3.1132 - val_accuracy: 0.4364
# 0.4364406779661017
# CPU times: user 9min 26s, sys: 4min 6s, total: 13min 33s
# Wall time: 19min 28s

# %% [markdown]
# ### Prevent-overfitting
# ---

# %%
# %%time
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=64, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same",
                           input_shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3])),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    
    tf.keras.layers.Conv2D(filters=128, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.Conv2D(filters=128, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    
    tf.keras.layers.Conv2D(filters=256, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.Conv2D(filters=256, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(128, activation = "relu", 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.4),
    tf.keras.layers.Dense(64, activation = "relu", 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.01),
    tf.keras.layers.Dense(10, activation = "linear")
])
## get output layer as logits for each class 
##(we can use softmax to get probabilities, but doing so makes model unstable:
# https://www.tensorflow.org/tutorials/quickstart/beginner
model.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

start = time.time()
fit = model.fit(trainX, trainY,
                validation_data = (testX,testY),
                epochs = 100,
                callbacks = [callback])
stop = time.time()
train_times.append(stop-start)


plot_results(fit)

probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
predictions = probability_model.predict(testX)
pred_labels = [np.argmax(prediction) for i,prediction in enumerate(predictions)]

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

ConfusionMatrixDisplay.from_predictions(
    y_true = [inv_labels[e] for i,e in enumerate(testY)],
    y_pred = [inv_labels[e] for i,e in enumerate(pred_labels)], 
    xticks_rotation= "vertical")
print(accuracy_score(testY,pred_labels))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 128, 1293, 64)     640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 647, 64)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 647, 128)      73856
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 647, 128)      147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 32, 324, 128)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 324, 256)      295168
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 324, 256)      590080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 162, 256)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 663552)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               84934784
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                650
# =================================================================
# Total params: 86,051,018
# Trainable params: 86,051,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
#
100
# 23/23 [==============================] - 39s 2s/step - loss: 0.7240 - accuracy: 0.8837 - val_loss: 2.3438 - val_accuracy: 0.5381
# Epoch 26/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.6046 - accuracy: 0.9300 - val_loss: 2.6740 - val_accuracy: 0.5466
# Epoch 27/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.5814 - accuracy: 0.9180 - val_loss: 2.6110 - val_accuracy: 0.5466
# Epoch 28/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.5869 - accuracy: 0.9341 - val_loss: 2.3226 - val_accuracy: 0.5508
# Epoch 29/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.6106 - accuracy: 0.9224 - val_loss: 2.8140 - val_accuracy: 0.5381
# Epoch 30/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.5986 - accuracy: 0.9178 - val_loss: 2.4328 - val_accuracy: 0.5339
# Epoch 31/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.5019 - accuracy: 0.9484 - val_loss: 2.6644 - val_accuracy: 0.5297
# Epoch 32/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.4911 - accuracy: 0.9440 - val_loss: 2.7676 - val_accuracy: 0.5932
# Epoch 33/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.5284 - accuracy: 0.9389 - val_loss: 2.7332 - val_accuracy: 0.5042
# Epoch 34/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.6019 - accuracy: 0.9221 - val_loss: 2.2630 - val_accuracy: 0.4915
# Epoch 35/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.5950 - accuracy: 0.9331 - val_loss: 2.6909 - val_accuracy: 0.5424
# Epoch 36/100
# 23/23 [==============================] - 39s 2s/step - loss: 0.6844 - accuracy: 0.9099 - val_loss: 2.6847 - val_accuracy: 0.5169
# Epoch 37/100
# 23/23 [==============================] - 40s 2s/step - loss: 0.6148 - accuracy: 0.9111 - val_loss: 2.6495 - val_accuracy: 0.5466
# 0.5466101694915254
# CPU times: user 12min 13s, sys: 5min 12s, total: 17min 26s
# Wall time: 24min 18s

# %% [markdown]
# ### With Batch Normalization

# %%
# %%time
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=64, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same",
                           input_shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3])),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=32, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=16, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.Conv2D(filters=16, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = "relu", 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(64, activation = "relu", 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.01),
    tf.keras.layers.Dense(10, activation = "linear")
])
## get output layer as logits for each class 
##(we can use softmax to get probabilities, but doing so makes model unstable:
# https://www.tensorflow.org/tutorials/quickstart/beginner
model.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

start = time.time()
fit = model.fit(trainX, trainY,
                validation_data = (testX,testY),
                epochs = 100,
                callbacks = [callback])
stop = time.time()
train_times.append(stop-start)


plot_results(fit)

probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
predictions = probability_model.predict(testX)
pred_labels = [np.argmax(prediction) for i,prediction in enumerate(predictions)]

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

ConfusionMatrixDisplay.from_predictions(
    y_true = [inv_labels[e] for i,e in enumerate(testY)],
    y_pred = [inv_labels[e] for i,e in enumerate(pred_labels)], 
    xticks_rotation= "vertical")
print(accuracy_score(testY,pred_labels))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 128, 1293, 64)     640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 64, 647, 64)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 647, 64)       256
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 647, 32)       18464
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 32, 324, 32)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 324, 32)       128
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 324, 16)       4624
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 324, 16)       2320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 162, 16)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 162, 16)       64
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               5308544
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                650
# =================================================================
# Total params: 5,343,946
# Trainable params: 5,343,722
# Non-trainable params: 224
# _________________________________________________________________
# Epoch 1/100
# 23/23 [==============================] - 10s 373ms/step - loss: 6.4465 - accuracy: 0.1850 - val_loss: 2.8321 - val_accuracy: 0.1144
# Epoch 2/100
# 23/23 [==============================] - 8s 337ms/step - loss: 2.4573 - accuracy: 0.3014 - val_loss: 3.0104 - val_accuracy: 0.1059
# Epoch 3/100
# 23/23 [==============================] - 8s 337ms/step - loss: 2.1567 - accuracy: 0.4242 - val_loss: 3.0450 - val_accuracy: 0.1059
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=64, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same",
                           input_shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3])),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=32, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=32, kernel_size =(2,2), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=16, kernel_size =(1,1), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(1,1), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation = "relu", 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(10, activation = "linear")
])
## get output layer as logits for each class 
##(we can use softmax to get probabilities, but doing so makes model unstable:
# https://www.tensorflow.org/tutorials/quickstart/beginner
model.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

start = time.time()
fit = model.fit(trainX, trainY,
                validation_data = (testX,testY),
                epochs = 100,
                callbacks = [callback])
stop = time.time()
train_times.append(stop-start)


plot_results(fit)

probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
predictions = probability_model.predict(testX)
pred_labels = [np.argmax(prediction) for i,prediction in enumerate(predictions)]

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

ConfusionMatrixDisplay.from_predictions(
    y_true = [inv_labels[e] for i,e in enumerate(testY)],
    y_pred = [inv_labels[e] for i,e in enumerate(pred_labels)], 
    xticks_rotation= "vertical")
print(accuracy_score(testY,pred_labels))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 128, 1293, 64)     640
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 64, 647, 64)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 647, 64)       256
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 64, 647, 32)       18464
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 32, 324, 32)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 324, 32)       128
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 32, 324, 32)       4128
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 16, 162, 32)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 162, 32)       128
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 162, 16)       528
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 162, 16)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 162, 16)       64
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                2654272
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                650
# =================================================================
# Total params: 2,679,258
# Trainable params: 2,678,970
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/100
# 23/23 [==============================] - 9s 354ms/step - loss: 4.4801 - accuracy: 0.1838 - val_loss: 2.6567 - val_accuracy: 0.1271
# Epoch 2/100
# 23/23 [==============================] - 8s 337ms/step - loss: 2.2418 - accuracy: 0.2573 - val_loss: 2.6302 - val_accuracy: 0.1059
# Epoch 3/100
# 23/23 [==============================] - 8s 335ms/step - loss: 2.0509 - accuracy: 0.3291 - val_loss: 2.8298 - val_accuracy: 0.1653
# Epoch 4/100
# 23/23 [==============================] - 8s 337ms/step - loss: 1.8804 - accuracy: 0.4292 - val_loss: 2.7264 - val_accuracy: 0.0297
# Epoch 5/100
# 23/23 [==============================] - 8s 335ms/step - loss: 1.9912 - accuracy: 0.3846 - val_loss: 3.3789 - val_accuracy: 0.0975
# Epoch 6/100
# 23/23 [==============================] - 8s 335ms/step - loss: 1.7068 - accuracy: 0.4938 - val_loss: 3.1292 - val_accuracy: 0.0975
# Epoch 7/100
# 23/23 [==============================] - 8s 335ms/step - loss: 1.5594 - accuracy: 0.5152 - val_loss: 3.5708 - val_accuracy: 0.1059
# Epoch 8/100
# 23/23 [==============================] - 8s 336ms/step - loss: 1.4027 - accuracy: 0.5808 - val_loss: 6.0186 - val_accuracy: 0.0975
# Epoch 9/100
# 23/23 [==============================] - 8s 335ms/step - loss: 1.3768 - accuracy: 0.5736 - val_loss: 7.1293 - val_accuracy: 0.0975
# Epoch 10/100
# 23/23 [==============================] - 8s 336ms/step - loss: 1.3362 - accuracy: 0.6149 - val_loss: 8.9310 - val_accuracy: 0.0975
# Epoch 11/100
# 23/23 [==============================] - 8s 336ms/step - loss: 1.2698 - accuracy: 0.6573 - val_loss: 4.4411 - val_accuracy: 0.1864
# Epoch 12/100
# 23/23 [==============================] - 8s 335ms/step - loss: 1
100
# 23/23 [==============================] - 8s 336ms/step - loss: 0.9053 - accuracy: 0.8362 - val_loss: 7.2117 - val_accuracy: 0.3347
# Epoch 38/100
# 23/23 [==============================] - 8s 336ms/step - loss: 0.7752 - accuracy: 0.8590 - val_loss: 3.3866 - val_accuracy: 0.5381
# 0.538135593220339
# CPU times: user 2min 19s, sys: 56 s, total: 3min 15s
# Wall time: 4min 55s

# %%
# %%time
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=64, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same",
                           input_shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3])),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=32, kernel_size =(3,3), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=32, kernel_size =(2,2), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=16, kernel_size =(1,1), strides = (1,1),
                           activation = "relu", padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(1,1), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation = "relu", 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(10, activation = "linear")
])
## get output layer as logits for each class 
##(we can use softmax to get probabilities, but doing so makes model unstable:
# https://www.tensorflow.org/tutorials/quickstart/beginner
model.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

start = time.time()
fit = model.fit(trainX, trainY,
                validation_data = (testX,testY),
                epochs = 100, batch_size = 5,
                callbacks = [callback])
stop = time.time()
train_times.append(stop-start)


plot_results(fit)

probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
predictions = probability_model.predict(testX)
pred_labels = [np.argmax(prediction) for i,prediction in enumerate(predictions)]

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

ConfusionMatrixDisplay.from_predictions(
    y_true = [inv_labels[e] for i,e in enumerate(testY)],
    y_pred = [inv_labels[e] for i,e in enumerate(pred_labels)], 
    xticks_rotation= "vertical")
print(accuracy_score(testY,pred_labels))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 128, 1293, 64)     640
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 64, 647, 64)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64, 647, 64)       256
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 64, 647, 32)       18464
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 32, 324, 32)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 324, 32)       128
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 32, 324, 32)       4128
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 16, 162, 32)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 162, 32)       128
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 16, 162, 16)       528
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 16, 162, 16)       0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 162, 16)       64
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                2654272
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                650
# =================================================================
# Total params: 2,679,258
# Trainable params: 2,678,970
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - 10s 65ms/step - loss: 4.2320 - accuracy: 0.1538 - val_loss: 2.7225 - val_accuracy: 0.0932
# Epoch 2/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.5249 - accuracy: 0.0922 - val_loss: 5.9244 - val_accuracy: 0.1017
# Epoch 3/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.5443 - accuracy: 0.0853 - val_loss: 5.9956 - val_accuracy: 0.0508
# Epoch 4/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.5448 - accuracy: 0.1306 - val_loss: 2.4559 - val_accuracy: 0.1907
# Epoch 5/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.5378 - accuracy: 0.1337 - val_loss: 2.4902 - val_accuracy: 0.1568
# Epoch 6/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.4492 - accuracy: 0.1736 - val_loss: 2.4364 - val_accuracy: 0.1737
# Epoch 7/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.4299 - accuracy: 0.1697 - val_loss: 2.3956 - val_accuracy: 0.1780
# Epoch 8/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.3710 - accuracy: 0.1699 - val_loss: 2.3900 - val_accuracy: 0.1780
# Epoch 9/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.4475 - accuracy: 0.1286 - val_loss: 4.0286 - val_accuracy: 0.1483
# Epoch 10/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.4633 - accuracy: 0.1658 - val_loss: 8.0624 - val_accuracy: 0.1653
# Epoch 11/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.4644 - accuracy: 0.1726 - val_loss: 2.4582 - val_accuracy: 0.1610
# Epoch 12/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.5622 - accuracy: 0.1839 - val_loss: 2.8069 - val_accuracy: 0.2203
# Epoch 13/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.3915 - accuracy: 0.1836 - val_loss: 2.4381 - val_accuracy: 0.1653
# Epoch 14/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.3062 - accuracy: 0.2227 - val_loss: 2.3483 - val_accuracy: 0.1907
# Epoch 15/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.3225 - accuracy: 0.2024 - val_loss: 3.6419 - val_accuracy: 0.1780
# Epoch 16/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.3603 - accuracy: 0.2198 - val_loss: 2.6993 - val_accuracy: 0.1568
# Epoch 17/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.4602 - accuracy: 0.2080 - val_loss: 2.5483 - val_accuracy: 0.1483
# Epoch 18/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.4928 - accuracy: 0.1935 - val_loss: 2.3887 - val_accuracy: 0.2288
# Epoch 19/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.3456 - accuracy: 0.2060 - val_loss: 2.4004 - val_accuracy: 0.2076
# Epoch 20/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.3787 - accuracy: 0.1851 - val_loss: 2.2938 - val_accuracy: 0.2331
# Epoch 21/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.3395 - accuracy: 0.2353 - val_loss: 2.8373 - val_accuracy: 0.1653
# Epoch 22/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.6087 - accuracy: 0.2093 - val_loss: 3.2950 - val_accuracy: 0.2076
# Epoch 23/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.4981 - accuracy: 0.1819 - val_loss: 2.5593 - val_accuracy: 0.1695
# Epoch 24/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.4525 - accuracy: 0.1834 - val_loss: 2.4833 - val_accuracy: 0.1737
# Epoch 25/100
# 142/142 [==============================] - 8s 59ms/step - loss: 2.4014 - accuracy: 0.1727 - val_loss: 3.6124 - val_accuracy: 0.1992
# 0.19915254237288135
# CPU times: user 1min 55s, sys: 37.3 s, total: 2min 33s
# Wall time: 3min 32s

# %% [markdown]
# ### Thus, the best predictions are around 50% when using only the MFCC.

# %% [markdown]
# # Use SeLu
# ---

# %%
# %%time
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=64, kernel_size =(3,3), strides = (1,1),
                           activation = "selu", kernel_initializer='lecun_normal',
                           padding = "same",
                           input_shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3])),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=32, kernel_size =(3,3), strides = (1,1),
                           activation = "selu", kernel_initializer='lecun_normal',
                           padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=32, kernel_size =(2,2), strides = (1,1),
                           activation = "selu", kernel_initializer='lecun_normal',
                           padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=16, kernel_size =(1,1), strides = (1,1),
                           activation = "selu", kernel_initializer='lecun_normal',
                           padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(1,1), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation = "selu",  
                          kernel_initializer='lecun_normal', 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(10, activation = "linear")
])
## get output layer as logits for each class 
##(we can use softmax to get probabilities, but doing so makes model unstable:
# https://www.tensorflow.org/tutorials/quickstart/beginner
model.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

start = time.time()
fit = model.fit(trainX, trainY,
                validation_data = (testX,testY),
                epochs = 100, batch_size = 5)#,callbacks = [callback])
stop = time.time()
train_times.append(stop-start)


plot_results(fit)

probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
predictions = probability_model.predict(testX)
pred_labels = [np.argmax(prediction) for i,prediction in enumerate(predictions)]

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

ConfusionMatrixDisplay.from_predictions(
    y_true = [inv_labels[e] for i,e in enumerate(testY)],
    y_pred = [inv_labels[e] for i,e in enumerate(pred_labels)], 
    xticks_rotation= "vertical")
print(accuracy_score(testY,pred_labels))
# Out:
# 2022-04-24 11:55:17.314433: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-24 11:55:17.318435: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-04-24 11:55:17.470046: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0a:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 11:55:17.471651: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:0b:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 11:55:17.473314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:16:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 11:55:17.474894: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:19:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 11:55:17.474924: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-24 11:55:17.643937: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-24 11:55:17.643978: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-24 11:55:17.713955: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-24 11:55:17.833850: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-24 11:55:17.949683: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04
100
# 142/142 [==============================] - 9s 67ms/step - loss: 1.2259 - accuracy: 0.9737 - val_loss: 4.3953 - val_accuracy: 0.4788
# Epoch 97/100
# 142/142 [==============================] - 9s 67ms/step - loss: 1.2783 - accuracy: 0.9662 - val_loss: 2.9301 - val_accuracy: 0.5932
# Epoch 98/100
# 142/142 [==============================] - 9s 67ms/step - loss: 1.1680 - accuracy: 0.9810 - val_loss: 3.3946 - val_accuracy: 0.5127
# Epoch 99/100
# 142/142 [==============================] - 9s 66ms/step - loss: 1.0831 - accuracy: 0.9870 - val_loss: 2.8020 - val_accuracy: 0.5720
# Epoch 100/100
# 142/142 [==============================] - 9s 66ms/step - loss: 0.8986 - accuracy: 0.9957 - val_loss: 2.4361 - val_accuracy: 0.5720
# 0.5720338983050848
# CPU times: user 7min 44s, sys: 2min 48s, total: 10min 33s
# Wall time: 16min 3s

# %%
# %%time
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=64, kernel_size =(3,3), strides = (1,1),
                           activation = "relu",
                           padding = "same",
                           input_shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3])),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=32, kernel_size =(3,3), strides = (1,1),
                           activation = "relu",
                           padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=32, kernel_size =(2,2), strides = (1,1),
                           activation = "relu",
                           padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(2,2), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=16, kernel_size =(1,1), strides = (1,1),
                           activation = "relu",
                           padding = "same"),
    tf.keras.layers.MaxPool2D(pool_size=(1,1), padding = "same"),
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation = "selu",  
                          kernel_initializer='lecun_normal', 
                          kernel_regularizer = tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(10, activation = "linear")
])
## get output layer as logits for each class 
##(we can use softmax to get probabilities, but doing so makes model unstable:
# https://www.tensorflow.org/tutorials/quickstart/beginner
model.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

start = time.time()
fit = model.fit(trainX, trainY,
                validation_data = (testX,testY),
                epochs = 100, batch_size = 5)#,callbacks = [callback])
stop = time.time()
train_times.append(stop-start)


plot_results(fit)

probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
predictions = probability_model.predict(testX)
pred_labels = [np.argmax(prediction) for i,prediction in enumerate(predictions)]

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

ConfusionMatrixDisplay.from_predictions(
    y_true = [inv_labels[e] for i,e in enumerate(testY)],
    y_pred = [inv_labels[e] for i,e in enumerate(pred_labels)], 
    xticks_rotation= "vertical")
print(accuracy_score(testY,pred_labels))
# Out:
# 2022-04-24 16:29:11.523094: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-24 16:29:11.527277: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-04-24 16:29:11.683789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0a:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 16:29:11.685488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:0b:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 16:29:11.687153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:16:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 16:29:11.688780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:19:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 16:29:11.688809: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-24 16:29:11.850953: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-24 16:29:11.851010: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-24 16:29:11.919486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-24 16:29:12.078246: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-24 16:29:12.203602: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-24 16:29:12.294568: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-24 16:29:12.429891: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-24 16:29:12.442314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2022-04-24 16:29:12.443155: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-24 16:29:12.443454: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-24 16:29:12.775280: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0a:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 16:29:12.776805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:0b:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 16:29:12.778263: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:16:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 16:29:12.779838: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:19:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2022-04-24 16:29:12.779892: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-24 16:29:12.779917: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-24 16:29:12.779937: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-24 16:29:12.779957: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-24 16:29:12.779976: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-24 16:29:12.779994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-24 16:29:12.780013: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-24 16:29:12.780033: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-24 16:29:12.791995: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2022-04-24 16:29:12.792069: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-24 16:29:16.608513: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-24 16:29:16.608554: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1 2 3
# 2022-04-24 16:29:16.608611: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y Y Y
# 2022-04-24 16:29:16.608617: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N Y Y
# 2022-04-24 16:29:16.608621: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 2:   Y Y N Y
# 2022-04-24 16:29:16.608626: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 3:   Y Y Y N
# 2022-04-24 16:29:16.618363: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10624 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:0a:00.0, compute capability: 3.7)
# 2022-04-24 16:29:16.642905: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10624 MB memory) -> physical GPU (device: 1, name: Tesla K80, pci bus id: 0000:0b:00.0, compute capability: 3.7)
# 2022-04-24 16:29:16.646213: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10624 MB memory) -> physical GPU (device: 2, name: Tesla K80, pci bus id: 0000:16:00.0, compute capability: 3.7)
# 2022-04-24 16:29:16.649510: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 10624 MB memory) -> physical GPU (device: 3, name: Tesla K80, pci bus id: 0000:19:00.0, compute capability: 3.7)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 1293, 64)     640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 647, 64)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 647, 64)       256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 647, 32)       18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 324, 32)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 324, 32)       128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 324, 32)       4128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 162, 32)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 162, 32)       128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 162, 16)       528
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 162, 16)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 162, 16)       64
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2654272
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 2,679,258
# Trainable params: 2,678,970
# Non-trainable params: 288
# _________________________________________________________________
# 2022-04-24 16:29:17.303575: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-04-24 16:29:17.304587: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2399810000 Hz
# Epoch 1/100
# 2022-04-24 16:29:18.152890: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-24 16:29:18.951264: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 142/142 [==============================] - 20s 107ms/step - loss: 7.4435 - accuracy: 0.1652 - val_loss: 10.7677 - val_accuracy: 0.1144
# Epoch 2/100
# 142/142 [==============================] - 9s 63ms/step - loss: 3.3249 - accuracy: 0.1697 - val_loss: 12.7176 - val_accuracy: 0.1483
# Epoch 3/100
# 142/142 [==============================] - 9s 63ms/step - loss: 3.2192 - accuracy: 0.1843 - val_loss: 9.7622 - val_accuracy: 0.1525
# Epoch 4/100
# 142/142 [==============================] - 9s 63ms/step - loss: 3.0025 - accuracy: 0.2354 - val_loss: 3.8672 - val_accuracy: 0.1610
# Epoch 5/100
# 142/142 [==============================] - 9s 63ms/step - loss: 2.9912 - accuracy: 0.1963 - val_loss: 2.5617 - val_accuracy: 0.2458
# Epoch 6/100
# 142/142 [==============================] - 9s 63ms/step - loss: 2.5784 - accuracy: 0.2985 - val_loss: 2.6874 - val_accuracy: 0.3263
# Epoch 7/100
# 142/142 [==============================] - 9s 63ms/step - loss: 2.4605 - accuracy: 0.3265 - val_loss: 11.7523 - val_accuracy: 0.1610
# Epoch 8/100
# 142/142 [==============================] - 9s 63ms/step - loss: 2.4596 - accuracy: 0.3486 - val_loss: 33.5412 - val_accuracy: 0.2331
# Epoch 9/100
# 142/142 [==============================] - 9s 63ms/step - loss: 2.2910 - accuracy: 0.4145 - val_loss: 2.5449 - val_accuracy: 0.3517
# Epoch 10/100
# 142/142 [==============================] - 9s 63ms/step - loss: 2